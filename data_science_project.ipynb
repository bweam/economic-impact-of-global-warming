# %% [markdown]
# # https://ourworldindata.org/co2/country/united-states?country=~USA
#
# datas:
# https://ourworldindata.org/grapher/co2-mitigation-2c
# https://ourworldindata.org/grapher/co2-mitigation-15c
# https://ourworldindata.org/grapher/econimpact2c
# https://ourworldindata.org/grapher/econimpact15c

# %%
import pandas as pd
import seaborn as sbs
import matplotlib.pyplot as pyplot


df = pd.read_csv("annual-co2-emissions-per-country.csv")

# %%
df.head()
# Out:
#         Entity Code  Year  Annual CO2 emissions
# 0  Afghanistan  AFG  1949              0.014656
# 1  Afghanistan  AFG  1950              0.084272
# 2  Afghanistan  AFG  1951              0.091600
# 3  Afghanistan  AFG  1952              0.091600
# 4  Afghanistan  AFG  1953              0.106256

# %%
df.columns=['country','code','yr','emissions']

# %%
df[df['country']=='United States']
# Out:
#              country code    yr    emissions
# 22026  United States  USA  1751     0.000000
# 22027  United States  USA  1752     0.000000
# 22028  United States  USA  1753     0.000000
# 22029  United States  USA  1754     0.000000
# 22030  United States  USA  1755     0.000000
# ...              ...  ...   ...          ...
# 22289  United States  USA  2014  5572.106312
# 22290  United States  USA  2015  5422.965677
# 22291  United States  USA  2016  5306.662457
# 22292  United States  USA  2017  5270.748525
# 22293  United States  USA  2018  5416.277883
#
# [268 rows x 4 columns]

# %%
globalEmission = df[df['country']=='World'].groupby('yr').sum()
globalEmission.drop(globalEmission.index[0:47], 0, inplace=True)
globalEmission = globalEmission.reset_index()
dimensions = (40, 20)
fig, ax = pyplot.subplots(figsize = dimensions)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Emission',fontsize=30)
ax.set_xticklabels(labels=globalEmission['yr'],Rotation=90)
globalPlot = sbs.barplot(data = globalEmission, x = 'yr', y = 'emissions')
globalPlot.set_title("Global CO2 Emissions (1800 - 2018)", fontsize=50)
globalPlot.set_yticklabels(globalPlot.get_yticks(),size=20)
# Out:
# [Text(0, 0, '0.0'),
#  Text(0, 0, '5000.0'),
#  Text(0, 0, '10000.0'),
#  Text(0, 0, '15000.0'),
#  Text(0, 0, '20000.0'),
#  Text(0, 0, '25000.0'),
#  Text(0, 0, '30000.0'),
#  Text(0, 0, '35000.0'),
#  Text(0, 0, '40000.0')]

# %%
USEmission = df[df['country'] == 'United States']
USEmission.drop(USEmission.index[0:47], 0, inplace=True)
fig, ax = pyplot.subplots(figsize = dimensions)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Emission',fontsize=30)
ax.set_xticklabels(labels=globalEmission['yr'],Rotation=90)
USPlot = sbs.barplot(data = USEmission, x='yr', y='emissions')
USPlot.set_title("US' CO2 Emissions (1800-2018)", fontsize=50)
USPlot.set_yticklabels(USPlot.get_yticks(),size=20)
USEmission
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#              country code    yr    emissions
# 22073  United States  USA  1798     0.000000
# 22074  United States  USA  1799     0.000000
# 22075  United States  USA  1800     0.252816
# 22076  United States  USA  1801     0.267472
# 22077  United States  USA  1802     0.289456
# ...              ...  ...   ...          ...
# 22289  United States  USA  2014  5572.106312
# 22290  United States  USA  2015  5422.965677
# 22291  United States  USA  2016  5306.662457
# 22292  United States  USA  2017  5270.748525
# 22293  United States  USA  2018  5416.277883
#
# [221 rows x 4 columns]

# %%
THEmission = df[df['country'] == 'Thailand']
fig, ax = pyplot.subplots(figsize = dimensions)
ax.set_xticklabels(labels=globalEmission['yr'],Rotation=90)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Emission',fontsize=30)
THPlot = sbs.barplot(data = THEmission, x='yr', y='emissions')
THPlot.set_title("Thailand's CO2 Emissions(1931-2018)", fontsize=50)
THPlot.set_yticklabels(THPlot.get_yticks(),size=20)
THEmission
# Out:
#         country code    yr   emissions
# 20708  Thailand  THA  1931    0.029312
# 20709  Thailand  THA  1932    0.025648
# 20710  Thailand  THA  1933    0.021984
# 20711  Thailand  THA  1934    0.025648
# 20712  Thailand  THA  1935    0.025648
# ...         ...  ...   ...         ...
# 20788  Thailand  THA  2014  277.979115
# 20789  Thailand  THA  2015  281.266911
# 20790  Thailand  THA  2016  280.371049
# 20791  Thailand  THA  2017  285.153346
# 20792  Thailand  THA  2018  288.229160
#
# [85 rows x 4 columns]

# %%
CNEmission = df[df['country'] == 'China']
CNEmission.drop(CNEmission.index[0:148], 0, inplace=True)
fig, ax = pyplot.subplots(figsize = dimensions)
ax.set_xticklabels(labels=globalEmission['yr'],Rotation=90)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Emission',fontsize=30)
CNPlot =sbs.barplot(data = CNEmission, x='yr', y='emissions')
CNPlot.set_title("China's CO2 Emissions (1899-2018)", fontsize=50)
CNPlot.set_yticklabels(CNPlot.get_yticks(),size=20)
CNEmission
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#      country code    yr     emissions
# 4434   China  CHN  1899      0.095264
# 4435   China  CHN  1902      0.095264
# 4436   China  CHN  1903      1.963904
# 4437   China  CHN  1904      2.088480
# 4438   China  CHN  1905      2.297328
# ...      ...  ...   ...           ...
# 4547   China  CHN  2014   9820.360492
# 4548   China  CHN  2015   9716.467840
# 4549   China  CHN  2016   9704.479432
# 4550   China  CHN  2017   9838.754028
# 4551   China  CHN  2018  10064.685698
#
# [118 rows x 4 columns]

# %%
RUEmission = df[df['country'] == 'Russia']
fig, ax = pyplot.subplots(figsize = dimensions)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Emission',fontsize=30)
RUPlot =sbs.barplot(data = RUEmission, x='yr', y='emissions')
RUPlot.set_title("Russia's CO2 Emissions (1959-2018)", fontsize=50)
RUPlot.set_yticklabels(RUPlot.get_yticks(),size=20)

RUEmission
# Out:
#       country code    yr    emissions
# 17509  Russia  RUS  1959   852.611802
# 17510  Russia  RUS  1960   887.666390
# 17511  Russia  RUS  1961   915.342786
# 17512  Russia  RUS  1962   960.612217
# 17513  Russia  RUS  1963  1030.119055
# 17514  Russia  RUS  1964  1095.467674
# 17515  Russia  RUS  1965  1162.049186
# 17516  Russia  RUS  1966  1227.159260
# 17517  Russia  RUS  1967  1283.126780
# 17518  Russia  RUS  1968  1319.129642
# 17519  Russia  RUS  1969  1373.752256
# 17520  Russia  RUS  1970  1444.932490
# 17521  Russia  RUS  1971  1533.261879
# 17522  Russia  RUS  1972  1613.170802
# 17523  Russia  RUS  1973  1681.273717
# 17524  Russia  RUS  1974  1745.272384
# 17525  Russia  RUS  1975  1834.499315
# 17526  Russia  RUS  1976  1905.088686
# 17527  Russia  RUS  1977  1969.847544
# 17528  Russia  RUS  1978  2037.477122
# 17529  Russia  RUS  1979  2054.333992
# 17530  Russia  RUS  1980  2135.148388
# 17531  Russia  RUS  1981  2094.442060
# 17532  Russia  RUS  1982  2133.881546
# ...

# %%
JPEmission = df[df['country'] == 'Japan']
fig, ax = pyplot.subplots(figsize = dimensions)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Emission',fontsize=30)
ax.set_xticklabels(labels=globalEmission['yr'],Rotation=90)
JPPlot = sbs.barplot(data = JPEmission, x='yr', y='emissions')
JPPlot.set_title("Japan's CO2 Emissions (1868-2018)", fontsize=50)
JPPlot.set_yticklabels(JPPlot.get_yticks(),size=20)
JPEmission
# Out:
#       country code    yr    emissions
# 11421   Japan  JPN  1868     0.010992
# 11422   Japan  JPN  1869     0.018320
# 11423   Japan  JPN  1870     0.018320
# 11424   Japan  JPN  1871     0.025648
# 11425   Japan  JPN  1872     0.032976
# ...       ...  ...   ...          ...
# 11567   Japan  JPN  2014  1264.880417
# 11568   Japan  JPN  2015  1224.538510
# 11569   Japan  JPN  2016  1206.165678
# 11570   Japan  JPN  2017  1188.122473
# 11571   Japan  JPN  2018  1161.981125
#
# [151 rows x 4 columns]

# %%
INEmission = df[df['country'] == 'India']
INEmission.drop(INEmission.index[0:107], 0, inplace=True)
fig, ax = pyplot.subplots(figsize = dimensions)
ax.set_xticklabels(labels=globalEmission['yr'],Rotation=90)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Emission',fontsize=30)
INPlot =sbs.barplot(data = INEmission, x='yr', y='emissions')
INPlot.set_title("India's CO2 Emissions (1858-2018)", fontsize=50)
INPlot.set_yticklabels(INPlot.get_yticks(),size=20)
INEmission
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#       country code    yr    emissions
# 10237   India  IND  1858     0.436016
# 10238   India  IND  1859     0.703488
# 10239   India  IND  1860     0.710816
# 10240   India  IND  1861     0.549600
# 10241   India  IND  1862     0.608224
# ...       ...  ...   ...          ...
# 10382   India  IND  2014  2199.400041
# 10383   India  IND  2015  2298.170090
# 10384   India  IND  2016  2371.752346
# 10385   India  IND  2017  2456.954485
# 10386   India  IND  2018  2654.101042
#
# [150 rows x 4 columns]

# %%
UKEmission = df[df['country'] == 'United Kingdom']
fig, ax = pyplot.subplots(figsize = dimensions)
ax.set_xticklabels(labels=globalEmission['yr'],Rotation=90)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Emission',fontsize=30)
UKPlot =sbs.barplot(data = UKEmission, x='yr', y='emissions')
UKPlot.set_title("United Kingdom's CO2 Emissions (1751-2018)", fontsize=50)
UKPlot.set_yticklabels(UKPlot.get_yticks(),size=20)
UKEmission
# Out:
#               country code    yr   emissions
# 21722  United Kingdom  GBR  1751    9.350528
# 21723  United Kingdom  GBR  1752    9.354192
# 21724  United Kingdom  GBR  1753    9.354192
# 21725  United Kingdom  GBR  1754    9.357856
# 21726  United Kingdom  GBR  1755    9.361520
# ...               ...  ...   ...         ...
# 21985  United Kingdom  GBR  2014  438.874167
# 21986  United Kingdom  GBR  2015  422.412773
# 21987  United Kingdom  GBR  2016  399.838872
# 21988  United Kingdom  GBR  2017  387.387321
# 21989  United Kingdom  GBR  2018  379.039892
#
# [268 rows x 4 columns]

# %%
EmissionByCountry = df.pivot('yr', 'country', 'emissions')
EmissionByCountry
# Out:
# country  Afghanistan       Africa   Albania  ...    Zambia  Zanzibar   Zimbabwe
# yr                                           ...
# 1751             NaN     0.000000       NaN  ...       NaN       NaN        NaN
# 1752             NaN     0.000000       NaN  ...       NaN       NaN        NaN
# 1753             NaN     0.000000       NaN  ...       NaN       NaN        NaN
# 1754             NaN     0.000000       NaN  ...       NaN       NaN        NaN
# 1755             NaN     0.000000       NaN  ...       NaN       NaN        NaN
# ...              ...          ...       ...  ...       ...       ...        ...
# 2014        8.449878  1365.297815  5.485008  ...  4.255726       NaN  11.961612
# 2015        9.019514  1330.236714  4.612976  ...  4.295821       NaN  12.163132
# 2016        8.653351  1354.960916  4.532368  ...  4.837847       NaN  10.807433
# 2017        8.971072  1370.140327  4.651350  ...  5.121556       NaN  12.025880
# ...

# %%
EmissionBySomeCountries = EmissionByCountry[['China', 'United States', 'United Kingdom', 'Thailand', 'Japan', 'Russia', 'India']]

# %%
fig, ax = pyplot.subplots(figsize = dimensions)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Emission',fontsize=30)
bycountry_plot = sbs.lineplot(data = EmissionBySomeCountries,linewidth=4)
bycountry_plot.set_title('CO2 Emission', fontsize=50)
bycountry_plot.set_yticklabels(bycountry_plot.get_yticks(),size=20)
bycountry_plot.set_xticklabels(bycountry_plot.get_xticks(),size=20)
plt.setp(ax.get_legend().get_texts(), fontsize='22') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='32') # for legend title
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-d6daa9da454d> in <module>()
#       6 bycountry_plot.set_yticklabels(bycountry_plot.get_yticks(),size=20)
#       7 bycountry_plot.set_xticklabels(bycountry_plot.get_xticks(),size=20)
# ----> 8 plt.setp(ax.get_legend().get_texts(), fontsize='22') # for legend text
#       9 plt.setp(ax.get_legend().get_title(), fontsize='32') # for legend title
#
# NameError: name 'plt' is not defined

# %%
EmissionByContinent = EmissionByCountry[['Asia', 'Asia (excl. China & India)','Europe', 'North America', 'South America', 'Africa', 'Australia']]

# %%
fig, ax = pyplot.subplots(figsize = dimensions)
bycontinent_plot = sbs.lineplot(data = EmissionByContinent,linewidth=4)
bycontinent_plot.set_title('CO2 Emission By Continents', fontsize=50)
bycontinent_plot.set_yticklabels(bycontinent_plot.get_yticks(),size=20)
bycontinent_plot.set_xticklabels(bycontinent_plot.get_xticks(),size=20)
plt.setp(ax.get_legend().get_texts(), fontsize='22') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='32') # for legend title

# %%
from matplotlib import pyplot as plt

fig,ax=plt.subplots(figsize=(10,10))
sbs.heatmap(EmissionBySomeCountries.corr() , annot=True, linewidths=0, square=True)

# %% [markdown]
# #Temperature Anomaly

# %%
import pandas as pd

tempdf = pd.read_csv("temperature-anomaly.csv")

# %%
tempdf.head()
# Out:
#    Entity  Year  ...  Upper bound (95% CI)  Lower bound (95% CI)
# 0  Global  1850  ...                -0.339                -0.425
# 1  Global  1851  ...                -0.184                -0.274
# 2  Global  1852  ...                -0.196                -0.280
# 3  Global  1853  ...                -0.239                -0.321
# 4  Global  1854  ...                -0.218                -0.301
#
# [5 rows x 5 columns]

# %%
tempdf.set_index(tempdf['Year'], drop=True, inplace=True)

# %%
tempdf.drop(columns='Year',inplace=True)
tempdf.drop(columns='Entity',inplace=True)

# %%
from matplotlib import pyplot
import seaborn as sbs

dimensions = (40,20)
fig, ax = pyplot.subplots(figsize = dimensions)
tempPlot = sbs.lineplot(data = tempdf)
tempPlot.set_title('Average Temperature Anomaly, Global', fontsize=50)
# Out:
# Text(0.5, 1.0, 'Average Temperature Anomaly, Global')

# %% [markdown]
# ##Economic Impacts of Global Temperature Increment of 2°C

# %%
import pandas as pd
import seaborn as sbs

impact2c = pd.read_csv("econimpact2c.csv")

# %%
impact2c

# %%
impact2c.columns=['Country','Code','% change in annual GDP per Capita','17th percentile','83rd percentile','97.5th percentile','2.5th percentile']

# %%
import plotly.express as px
import numpy as np
import plotly.graph_objects as go

fig = go.Figure(data=go.Choropleth(
    locations=impact2c['Code'], # Spatial coordinates
    z = impact2c['% change in annual GDP per Capita'].astype(float), # Data to be color-coded
    colorscale = 'Rdbu',
    colorbar_title = "%", 
    customdata= impact2c['Country'],
    hovertemplate =
    "<b>%{customdata} </b><br><br>" +
    "%{z:.2f}%" +
    "<extra></extra>",
  ))

fig.update_layout(
    title={'text': 'Economic Impacts of Global Temperature Increment of 2°C',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

# fig = px.choropleth(impact2c['% change in annual GDP per Capita'], locations=impact2c['Code'], color=np.round(impact2c['% change in annual GDP per Capita'],0), hover_name=impact2c['Country'], range_color=[-4,2], color_continuous_scale='Rdbu', 
#                     title='Economic Impacts of Global Temperature Increment of 2°C')
fig.show()

# %%
print('Overall Global Annual GDP per Capita Impact as a Percentage: ' + str(np.round(impact2c['% change in annual GDP per Capita'].sum()/149,2)) +'%')
print()
print('As of 2019, the estimated average GDP per capita (PPP) of all of the countries of the world is $18,381 \nso -0.5% of such amount is: -0.5% x $18,381 = -$' + str(np.round((18381*0.5/100),2)) + '0')
print('\nThis means each person would earn, on average, $91.90 less anually from a 2.0°C increase in temperature alone.')

# %% [markdown]
# ##Economic Impacts of Global Temperature Increment of 1.5°C

# %%
import pandas as pd
import seaborn as sbs

impact15c = pd.read_csv("econimpact15c.csv")

# %%
impact15c

# %%
impact15c.columns=['Country','Code','% change in annual GDP per Capita','17th percentile','83rd percentile','97.5th percentile','2.5th percentile']

# %%
import plotly.express as px
import numpy as np
import plotly.graph_objects as go

fig = go.Figure(data=go.Choropleth(
    locations=impact15c['Code'], # Spatial coordinates
    z = impact15c['% change in annual GDP per Capita'].astype(float), # Data to be color-coded
    colorscale = 'Rdbu',
    colorbar_title = "%", 
    customdata= impact15c['Country'],
    hovertemplate =
    "<b>%{customdata} </b><br><br>" +
    "%{z:.2f}%" +
    "<extra></extra>",
  ))

fig.update_layout(
    title={'text': 'Economic Impacts of Global Temperature Increment of 1.5°C',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.show()

# %%
print('Overall Global Annual GDP per Capita Impact as a Percentage: ' + str(np.round(impact15c['% change in annual GDP per Capita'].sum()/149,2)) +'%')
print()
print('As of 2019, the estimated average GDP per capita (PPP) of all of the countries of the world is $18,381, \nso -0.25% of such amount is: -0.25% x $18,381 = -$' + str(np.round((18381*0.25/100),2)))
print('\nThis means each person would earn, on average, $45.95 less anually from a 1.5°C increase in temperature alone.')

# %% [markdown]
# ##CO₂ reductions needed to keep global temperature rise below 2.0°C

# %%
policy2c = pd.read_csv("co2-mitigation-2c.csv")

# %%
policy2c.head()

# %%
policy2c.columns=['Entity','Year','CO2 Tonnes']

# %%
policy2c.set_index(policy2c['Year'], drop=True, inplace=True)

# %%
policy2c.drop(policy2c.index[0:200], inplace=True)

# %%
import plotly.express as px
fig = px.line(policy2c, x="Year", y="CO2 Tonnes", color="Entity", line_group="Entity", hover_name="Year",
        line_shape="spline", render_mode="svg", title="CO₂ reductions needed to keep global temperature rise below 2.0°C")
fig.show()

# %% [markdown]
# ## CO₂ reductions needed to keep global temperature rise below 1.5°C

# %%
policy15c = pd.read_csv("co2-mitigation-15c.csv")

# %%
policy15c.set_index(policy15c['Year'], drop=True, inplace=True)
policy15c.columns=['Entity','Year','CO2 Tonnes']
policy15c.drop(policy15c.index[0:200], inplace=True)

# %%
import plotly.express as px
fig = px.line(policy15c, x="Year", y="CO2 Tonnes", color="Entity", line_group="Entity", hover_name="Year",
        line_shape="spline", render_mode="svg", title="CO₂ reductions needed to keep global temperature rise below 1.5°C")
fig.show()

# %% [markdown]
# #natural

# %% [markdown]
# Natural Disaster dataset: https://drive.google.com/file/d/1VSaLJ-8UTtp6kaALODfTQ94bcaPegVXU/view?usp=sharing Downloaded from emdat

# %%
from matplotlib import pyplot as plt
disasterDf = pd.read_csv('emdat_public_2020_11_02_query_uid-G7WTWp.csv',skiprows=6)
filteredDisaster = disasterDf[disasterDf['Disaster Type'].isin(['Flood','Drought','Storm','Wildfire','Extreme temperature'])]
filteredDisaster = filteredDisaster.groupby('Year').count()
filteredDisaster =filteredDisaster.reset_index()
fig, ax = pyplot.subplots(figsize = dimensions)
disastorPlot = sbs.barplot(data = filteredDisaster,x='Year',y='Dis No')
ax.set_xlabel(xlabel='Year',size=30)
ax.set_ylabel(ylabel='Frequency',size=30)
disastorPlot.set_title('Natural Disaster Frequency', fontsize=50)
disastorPlot.set_yticklabels(disastorPlot.get_yticks(),size=20)
disastorPlot.set_xticklabels(filteredDisaster['Year'],size=20)
plt.show()

# %% [markdown]
# #SF6

# %% [markdown]
# dataset: http://data.un.org/Data.aspx?d=GHG&f=seriesID%3ASF6

# %%
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sbs
dimensions = (40,20)
sfGas = pd.read_csv('sf6.csv')
sfGas = sfGas.groupby('Year').sum()
sfGas['Value'] = sfGas['Value'].astype(int)
sfGas = sfGas.reset_index()
fig, ax = plt.subplots(figsize = dimensions)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Emission',fontsize=30)
ax.set_xticklabels(sfGas['Year'],size=20)
sfPlot = sbs.barplot(data = sfGas,x='Year',y='Value').set_title('World SF6 Gas Emissions',fontsize=100)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-42-bc2701597375> in <module>()
#       3 import seaborn as sbs
#       4 dimensions = (40,20)
# ----> 5 sfGas = pd.read_csv('sf6.csv')
#       6 sfGas = sfGas.groupby('Year').sum()
#       7 sfGas['Value'] = sfGas['Value'].astype(int)
#
# ...

# %% [markdown]
# #Sea level

# %% [markdown]
# URL : https://drive.google.com/file/d/1HH136d0HMk7UOc6SNZvZpZrnZK8-6I5k/view?usp=sharing

# %%
import math
import seaborn as sbs
import matplotlib.pyplot as pyplot
import pandas as pd
seaLevel = pd.read_csv('sea_level.csv',skiprows=5)
def get_mean(data):
  listedData = (data.to_numpy().tolist())
  for n in range(len(listedData)):
    filteredArr = list(filter(lambda x: x!=0 and (not math.isnan(x)),listedData[n]))
    if len(filteredArr)!=0:
      summation = sum(filteredArr)/len(filteredArr)
    else:
      summation=0;
    listedData[n] = summation
  return listedData
seaLevel['year'] = seaLevel['year'].astype(int)
seaLevel['TOPEX/Poseidon'] = seaLevel['TOPEX/Poseidon'].fillna(0)
seaLevel['Sea level anomaly'] = get_mean(seaLevel[seaLevel.columns[1:]])
fig, ax = pyplot.subplots(figsize = (20,20))
formattedDf = seaLevel.groupby('year').mean()
seaPlot = sbs.lineplot(data=formattedDf,x='year',y='Sea level anomaly',linewidth=4)
seaPlot.set_title('Global Mean Sea Level Anomaly', fontsize=30)
seaPlot.set_yticklabels(seaPlot.get_yticks(),size=20)
ax.set_xlabel('Year',fontsize=30)
ax.set_ylabel('Sea Level Anomaly',fontsize=30)
seaPlot.set_xticklabels(seaPlot.get_xticks(),size=20)

# %% [markdown]
# #Correlation

# %%
import matplotlib.pyplot as plt
import seaborn as sbs
tempdf = pd.read_csv("temperature-anomaly.csv")
df = pd.read_csv("annual-co2-emissions-per-country.csv")
tempdf.set_index(tempdf['Year'], drop=True, inplace=True)
tempdf.drop(columns='Year',inplace=True)
tempdf.drop(columns='Entity',inplace=True)
df.drop(df[df['Year']< 1850].index,inplace=True)
globedf = df[df['Entity']=='World']
fig, ax1 = plt.subplots(figsize = (20,20))
ax1.set_xlabel('Year',fontsize=30)
ax1.set_ylabel('Emissions (Billion tons)',fontsize=20)
sbs.lineplot(data=globedf, x='Year',y='Annual CO2 emissions',color='red',linewidth=3)
ax2 = ax1.twinx()
ax2.set_ylabel('Temperature Anomaly (Celsius)',fontsize=20)
sbs.lineplot(data=tempdf,ax=ax2)
fig.legend(labels=['Annual Global CO2 Emission','Temperature Anomaly'])
plt.show()
